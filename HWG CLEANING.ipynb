# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\Edison New\\Desktop\\HWG file prep\\RTV Household Survey - HWG AHS 2025_WIDE2.csv",header=5)

# %%
# Filter column names containing "business_check"
filtered_columns = [i for i in data.columns if ("business" in i and "check" in i) | ("business" in i and "chk" in i) ]

# %%
filtered_columns
# Out:
# ['business2_assets_check',
#  'business2_stock_inventory_check',
#  'business2_stock_expenses_check',
#  'business2_expenses_check',
#  'business2_operation_expenses_check',
#  'business2_sales_chk',
#  'business2_profit_check',
#  'business3_assets_check',
#  'business3_stock_inventory_check',
#  'business3_stock_expenses_check',
#  'business3_expenses_check',
#  'business3_operation_expenses_check',
#  'business3_sales_chk',
#  'business3_profit_check',
#  'business4_assets_check',
#  'business4_stock_inventory_check',
#  'business4_stock_expenses_check',
#  'business4_expenses_check',
#  'business4_operation_expenses_check',
#  'business4_sales_chk',
#  'business4_profit_check',
#  'business5_assets_check',
#  'business5_stock_inventory_check',
#  'business5_stock_expenses_check',
#  'business5_expenses_check',
#  'business5_operation_expenses_check',
#  'business5_sales_chk',
#  'business5_profit_check',
#  'business6_assets_check',
#  'business6_stock_inventory_check',
# ...

# %%
data = data.drop(columns=filtered_columns)

# %%
data .to_csv("C:\\Users\\Edison New\\Desktop\\HWG file prep\\RTV Household Survey - HWG AHS 2025_WIDE12.csv",index=False)
